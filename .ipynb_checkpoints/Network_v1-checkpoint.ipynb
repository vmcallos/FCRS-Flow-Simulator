# %%
import pandas as pd
import math
from iapws import IAPWS97
import sys
import matplotlib.pyplot as plt

# %matplotlib inline
# %run conservation_equations_v2.ipynb

#sys.stdout = open("log.txt", "w")

# %%
class Test:
    def __repr__(self):
        return "Test()"
    #def __str__(self):
    #    return "member of Test"

t = Test()
print (t)
# Out:
# Test()

# %%
class node:
    def __init__(self, nodeID, P, mf, z):
        self.nodeID = nodeID
        self.P = P
        self.mf = mf
        self.z = z
    def __str__ (self):
        return "An instance of class Test with state: a=%.2f" % (self.mf)
        
class pipeline:
     def __init__(self, lineID, length, in_dia, roughness, pipe_t, insul_t, pipe_k, insul_k, n_elbow45, n_elbow90, n_tee, \
                 n_rbend, n_coupling, n_union, n_gatefull, n_gatehalf, out_dia):
        self.length = length
        self.in_dia = in_dia 
        self.roughness = roughness
        self.pipe_t = pipe_t 
        self.insul_t = insul_t 
        self.pipe_k = pipe_k
        self.insul_k = insul_k
        self.n_elbow45 = n_elbow45
        self.n_elbow90 = n_elbow90
        self.n_tee = n_tee
        self.n_rbend = n_rbend
        self.n_coupling = n_coupling
        self.n_union = n_union
        self.n_gatefull = n_gatefull
        self.n_gatehalf = n_gatehalf
        self.out_dia = out_dia     #for pipe expansion or contraction

# %%
node_df = pd.read_excel("bom.xls", sheetname=8, parse_cols="A:D")
pipeline_df = pd.read_excel("bom.xls", sheetname=7)
#print (pipeline_df.head())

node_dict = {}
pipeline_dict = {}

for nodes in range(len(node_df.index)):
    #create a node class for each row and store it in a dictionary
    nodeID, P, mf, z = map(lambda x: node_df.iloc[nodes, x], range(0,4))
    node_dict[nodeID] = node(nodeID, P, mf, z)

for pipelines in range(len(pipeline_df.index)):
    #create a pipeline class for each row and store it in a dictionary
    lineID, length, in_dia, roughness, pipe_t, insul_t, pipe_k, insul_k, n_elbow45, n_elbow90, n_tee, \
        n_rbend, n_coupling, n_union, n_gatefull, n_gatehalf, out_dia = \
        map(lambda x: pipeline_df.iloc[pipelines, x], range(0,17))   
    pipeline_dict[lineID] = pipeline(lineID, length, in_dia, roughness, pipe_t, insul_t, pipe_k, insul_k, \
        n_elbow45, n_elbow90, n_tee, n_rbend, n_coupling, n_union, n_gatefull, n_gatehalf, out_dia)

#print(node_dict.keys())
#print(pipeline_dict.keys())

for val in node_dict:
    print (node_dict[val])

def pressure_drop(z1, z2, Diameter, MassFlow, InletPressure, Length, Elbow_90, GateValve_FullyOpen, \
                  ThermalConductivity, InsulationThickness, Diameter2):
    '''Calculate parameters from steam table'''
    sat_steam = IAPWS97(P = InletPressure, x=1)
    temperature = sat_steam.T
    density = sat_steam.rho
    enthalpy =  sat_steam.h
    dynamic_viscosity = sat_steam.mu
    #print(temperature, density, dynamic_viscosity, enthalpy)
    
    '''Calculate Derived Parameters'''
    Diameter = Diameter
    #Relative roughness
    roughness = 0.000046
    relative_roughness = roughness / Diameter
    #cross sectional area
    area = math.pi * Diameter**2 / 4
    area2 = math.pi * Diameter2**2 / 4
    #velocity
    velocity = MassFlow / (density * area)
    velocity2 = MassFlow/ (density * area2)
    #print(velocity, velocity2)
    
    '''Skin Friction Calculation'''
    nRE = reynolds_number(Diameter, velocity, density, dynamic_viscosity)
    friction_factor = ff_colebrook(nRE, relative_roughness)
    friction_skin = f_skin(temperature, Diameter, velocity, relative_roughness, Length)
        
    '''Pipe Enlargement and contraction '''
    if area == area2:
        friction_expansion = 0
        friction_contraction = 0
    else:
        if area < area2:
            friction_expansion = f_expansion(area, area2, velocity)
            friction_contraction = 0
            #print('expansion')
        else:
            friction_expansion = 0
            friction_contraction = f_contraction(area, area2, velocity)
            #print('contraction')
    
    """Define Fittings"""
    #Represent in a list of 8
    fittings_list = [0, 0, 0, 0, 0, 0, 0, 0]
    fittings_list[1] = Elbow_90
    fittings_list[6] = GateValve_FullyOpen
    #fittings [0] = elbow_45  #fittings [1] = elbow_90
    #fittings [2] = tee       #fittings [3] = return_bend
    #fittings [4] = coupling  #fittings [5] = union
    #fittings [6] = gate_valve_full  #fittings [7] = gate_valve_half
    '''Losses in fittings and valves'''
    friction_fittings = f_fittings(velocity, fittings_list)
    #print (velocity, friction_fittings)
    
    '''Calulate total friction losses'''
    friction_total = friction_skin + friction_expansion + friction_contraction + friction_fittings
    
    
    '''Define Parameters for heat loss'''
    #Convective heat transfer coefficient (h; W/m**K)
    h_steam_pipe = 36
    h_insulation_air = 7
    #Insulation
    t_insulation = InsulationThickness          #insulation thickness (m)
    k_insulation = ThermalConductivity          #insulation's thermal conductivity (W/m** K)
    #Pipe
    t_pipe = 0.5 * 0.0254          #pipeline thickness (m)
    k_pipe = 56           #pipe's thermal conductivity (W/m** K)
    #id_pipe = 0.25        #pipe's inner diameter (m) given at diameter
    #l_pipe = 6000         #length of pipeline (m) given at length
    #Temp
    t1 = temperature - 273.15           #temp inside the pipeline
    t2 = 25                             #temp; atmospheric
    
    r1 = Diameter
    r2 = Diameter + t_pipe
    r3 = Diameter + t_pipe + t_insulation
    
    h_t = heat_transfer(Length, t1, t2, h_steam_pipe, h_insulation_air, k_pipe, k_insulation, r1, r2, r3)
    Q = h_t / MassFlow
    
    #print(Length, t1, t2, h_steam_pipe, h_insulation_air, k_pipe, k_insulation, r1, r2, r3, h_t, MassFlow)
    '''Calculate gdZ'''
    gdz = head(z1, z2)
    
    '''Calculate udu'''
    udu = (velocity**2 - velocity2**2)/2

    '''Calculate outlet pressure'''
    p2 = p_out(InletPressure, friction_total, gdz, udu, density, Q )
    t_loss = friction_total - Q + gdz + udu
    
    '''Calculate steam flow at the end of pipeline'''
    X = x_out(t_loss*-1e-3, InletPressure, p2)
    sf_out = X*MassFlow
    
    print('{:26}'.format('Velocity (m/s)'), '{:>16.2f}'.format(velocity))
    print('{:26}'.format('Tot Loss (J/kg)'), '{:>16.2f}'.format(t_loss))
    print('{:26}'.format('Heat Loss (J/kg)'), '{:>16.2f}'.format(-Q))
    print ('{:26}'.format('d K.E. (J/kg)'), '{:>16.2f}'.format(udu))
    print ('{:26}'.format('d P.E. (J/kg)'), '{:>16.2f}'.format(gdz))
    print ('{:26}'.format('Friction Loss (J/kg)'), '{:>16.2f}'.format(friction_total))
    print ('{:26}'.format('  Skin Friction (J/kg)'), '{:>16.2f}'.format(friction_skin))
    print ('{:26}'.format('  Expansion (J/kg)'), '{:>16.2f}'.format(friction_expansion))
    print ('{:26}'.format('  Contraction (J/kg)'), '{:>16.2f}'.format(friction_contraction))
    print ('{:26}'.format('  Fittings Friction (J/kg)'), '{:>16.2f}'.format(friction_fittings))
    print ('{:26}'.format('Inlet Pressure (Mpaa)'), '{:>16.2f}'.format(InletPressure))
    print ('{:26}'.format('Outlet Pressure (Mpaa)'), '{:>16.2f}'.format(p2))
    print('{:26}'.format('SF_in (kg/s)'), '{:>16.2f}'.format(MassFlow))
    print('{:26}'.format('SF_out (kg/s)'), '{:>16.2f}'.format(sf_out))
    data = (velocity, t_loss, -Q, friction_skin, friction_expansion, friction_contraction, friction_fittings, \
           InletPressure, p2, MassFlow, sf_out)
    
    return [p2, sf_out, data]
# Out:
# An instance of class Test with state: a=0.00
# An instance of class Test with state: a=0.00
# An instance of class Test with state: a=33.51
# An instance of class Test with state: a=0.00
# An instance of class Test with state: a=42.28
# An instance of class Test with state: a=0.00
# An instance of class Test with state: a=0.00
# An instance of class Test with state: a=50.64
# An instance of class Test with state: a=26.81
# An instance of class Test with state: a=39.31
# An instance of class Test with state: a=0.00
# An instance of class Test with state: a=51.19
# An instance of class Test with state: a=49.87
# An instance of class Test with state: a=0.00
# An instance of class Test with state: a=0.00

# %%
#given nodes 504 and 701 and STL504
#calc dp along STL 504
#print (node_dict['701A'].z)
#edge = {'STL504':[504, '701A']}
#
#t_loss = pressure_drop(node_dict[504].z, node_dict['701A'].z, pipeline_dict['STL504'].in_dia, node_dict[504].mf, \
#                       node_dict[504].P, pipeline_dict['STL504'].length, pipeline_dict['STL504'].n_elbow90, \
#                       pipeline_dict['STL504'].n_gatefull, pipeline_dict['STL504'].insul_k, \
#                       pipeline_dict['STL504'].insul_t, pipeline_dict['STL504'].out_dia)

# %%
edge = {'STL501':[501, '702A'], 'STL502':[502, '702A'], 'STL503':[503, '702A'], 'STL504':[504, '701A'], \
        'STL505':[505, '701A'], 'STL506':[506, '701B'], 'STL508':[508, '702C'], 'STL702A':['702A', '702B'], \
        'STL702B':['702B', '702C'], 'STL702IF':['702C', '702IF'], 'STL701A':['701A', '701B'], \
        'STL701B':['701B', '701C'], 'STL701IF':['701C', '701IF']}

#print (sorted(edge.keys())
node_out={}

for x in sorted(edge):
    #edge[x][0] for input node; edge[x][1] for output node; x for pipeline
    print('SteamLine', x, edge[x])
    #print (node_dict[edge[x][0]].z)
    t_loss = pressure_drop(node_dict[edge[x][0]].z, node_dict[edge[x][1]].z, pipeline_dict[x].in_dia, \
                       node_dict[edge[x][0]].mf, \
                       node_dict[edge[x][0]].P, pipeline_dict[x].length, pipeline_dict[x].n_elbow90, \
                       pipeline_dict[x].n_gatefull, pipeline_dict[x].insul_k, \
                       pipeline_dict[x].insul_t, pipeline_dict[x].out_dia)
    
    if node_dict[edge[x][1]].P == 0:
        node_dict[edge[x][1]].P = t_loss[0]
    else:
        node_dict[edge[x][1]].P = (node_dict[edge[x][1]].P + t_loss[0] )/2
    node_dict[edge[x][1]].mf += t_loss[1]
    #print(pipeline_dict[x].length, node_dict[edge[x][1]].mf)
    #print(x)
    node_out[x]= [node_dict[edge[x][1]].P, node_dict[edge[x][1]].mf]
    #add other input and output information in the dictionary
    for n in t_loss[2]:
        node_out[x].append(n)
    
        
    print ('\n', '===================================================', '\n')
# Out:
# SteamLine STL501 [501, '702A']
# Velocity (m/s)                        26.09
# Tot Loss (J/kg)                    11688.83
# Heat Loss (J/kg)                    6063.47
# d K.E. (J/kg)                        255.12
# d P.E. (J/kg)                        294.30
# Friction Loss (J/kg)                5075.94
#   Skin Friction (J/kg)              2806.29
#   Expansion (J/kg)                   170.05
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          2099.61
# Inlet Pressure (Mpaa)                  0.88
# Outlet Pressure (Mpaa)                 0.83
# SF_in (kg/s)                          50.64
# SF_out (kg/s)                         50.41
#
#  ===================================================
#
# SteamLine STL502 [502, '702A']
# Velocity (m/s)                        13.81
# Tot Loss (J/kg)                    13285.81
# Heat Loss (J/kg)                   11453.13
# d K.E. (J/kg)                         71.50
# d P.E. (J/kg)                        294.30
# Friction Loss (J/kg)                1466.88
#   Skin Friction (J/kg)               830.74
#   Expansion (J/kg)                    47.66
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)           588.48
# Inlet Pressure (Mpaa)                  0.88
# Outlet Pressure (Mpaa)                 0.82
# SF_in (kg/s)                          26.81
# SF_out (kg/s)                         26.67
#
#  ===================================================
#
# SteamLine STL503 [503, '702A']
# Velocity (m/s)                        20.25
# Tot Loss (J/kg)                    11351.74
# Heat Loss (J/kg)                    7812.60
# d K.E. (J/kg)                        153.67
# d P.E. (J/kg)                        294.30
# Friction Loss (J/kg)                3091.17
#   Skin Friction (J/kg)              1724.03
#   Expansion (J/kg)                   102.43
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          1264.71
# Inlet Pressure (Mpaa)                  0.88
# Outlet Pressure (Mpaa)                 0.83
# SF_in (kg/s)                          39.31
# SF_out (kg/s)                         39.13
#
#  ===================================================
#
# SteamLine STL504 [504, '701A']
# Velocity (m/s)                        21.78
# Tot Loss (J/kg)                     9918.69
# Heat Loss (J/kg)                    6101.15
# d K.E. (J/kg)                        177.80
# d P.E. (J/kg)                        392.40
# Friction Loss (J/kg)                3247.35
#   Skin Friction (J/kg)              1665.60
#   Expansion (J/kg)                   118.51
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          1463.24
# Inlet Pressure (Mpaa)                  0.88
# Outlet Pressure (Mpaa)                 0.84
# SF_in (kg/s)                          42.28
# SF_out (kg/s)                         42.11
#
#  ===================================================
#
# SteamLine STL505 [505, '701A']
# Velocity (m/s)                        26.37
# Tot Loss (J/kg)                    10417.70
# Heat Loss (J/kg)                    5038.69
# d K.E. (J/kg)                        260.68
# d P.E. (J/kg)                        392.40
# Friction Loss (J/kg)                4725.93
#   Skin Friction (J/kg)              2406.80
#   Expansion (J/kg)                   173.75
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          2145.38
# Inlet Pressure (Mpaa)                  0.88
# Outlet Pressure (Mpaa)                 0.84
# SF_in (kg/s)                          51.19
# SF_out (kg/s)                         50.98
#
#  ===================================================
#
# SteamLine STL506 [506, '701B']
# Velocity (m/s)                        25.69
# Tot Loss (J/kg)                    11189.30
# Heat Loss (J/kg)                    5788.39
# d K.E. (J/kg)                        247.36
# d P.E. (J/kg)                        392.40
# Friction Loss (J/kg)                4761.15
#   Skin Friction (J/kg)              2560.55
#   Expansion (J/kg)                   164.87
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          2035.73
# Inlet Pressure (Mpaa)                  0.88
# Outlet Pressure (Mpaa)                 0.83
# SF_in (kg/s)                          49.87
# SF_out (kg/s)                         49.65
#
#  ===================================================
#
# SteamLine STL508 [508, '702C']
# Velocity (m/s)                        19.36
# Tot Loss (J/kg)                     2207.02
# Heat Loss (J/kg)                     531.34
# d K.E. (J/kg)                        140.44
# d P.E. (J/kg)                        196.20
# Friction Loss (J/kg)                1339.04
#   Skin Friction (J/kg)                89.63
#   Expansion (J/kg)                    93.61
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          1155.80
# Inlet Pressure (Mpaa)                  0.78
# Outlet Pressure (Mpaa)                 0.77
# SF_in (kg/s)                          33.51
# SF_out (kg/s)                         33.48
#
#  ===================================================
#
# SteamLine STL701A ['701A', '701B']
# Velocity (m/s)                        25.10
# Tot Loss (J/kg)                     2565.76
# Heat Loss (J/kg)                     453.26
# d K.E. (J/kg)                          0.00
# d P.E. (J/kg)                          0.00
# Friction Loss (J/kg)                2112.50
#   Skin Friction (J/kg)               169.33
#   Expansion (J/kg)                     0.00
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          1943.17
# Inlet Pressure (Mpaa)                  0.84
# Outlet Pressure (Mpaa)                 0.83
# SF_in (kg/s)                          93.09
# SF_out (kg/s)                         93.00
#
#  ===================================================
#
# SteamLine STL701B ['701B', '701C']
# Velocity (m/s)                        38.80
# Tot Loss (J/kg)                     8779.62
# Heat Loss (J/kg)                    1770.12
# d K.E. (J/kg)                          0.00
# d P.E. (J/kg)                          0.00
# Friction Loss (J/kg)                7009.49
#   Skin Friction (J/kg)              2365.45
#   Expansion (J/kg)                     0.00
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          4644.04
# Inlet Pressure (Mpaa)                  0.83
# Outlet Pressure (Mpaa)                 0.79
# SF_in (kg/s)                         142.64
# SF_out (kg/s)                        142.17
#
#  ===================================================
#
# SteamLine STL701IF ['701C', '701IF']
# Velocity (m/s)                        40.42
# Tot Loss (J/kg)                    35545.17
# Heat Loss (J/kg)                    9931.68
# d K.E. (J/kg)                          0.00
# d P.E. (J/kg)                       -981.00
# Friction Loss (J/kg)               26594.50
#   Skin Friction (J/kg)             14341.10
#   Expansion (J/kg)                     0.00
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)         12253.40
# Inlet Pressure (Mpaa)                  0.79
# Outlet Pressure (Mpaa)                 0.64
# SF_in (kg/s)                         142.17
# SF_out (kg/s)                        140.36
#
#  ===================================================
#
# SteamLine STL702A ['702A', '702B']
# Velocity (m/s)                        31.67
# Tot Loss (J/kg)                     3720.93
# Heat Loss (J/kg)                     361.92
# d K.E. (J/kg)                          0.00
# d P.E. (J/kg)                          0.00
# Friction Loss (J/kg)                3359.01
#   Skin Friction (J/kg)               265.01
#   Expansion (J/kg)                     0.00
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          3094.00
# Inlet Pressure (Mpaa)                  0.83
# Outlet Pressure (Mpaa)                 0.81
# SF_in (kg/s)                         116.21
# SF_out (kg/s)                        116.05
#
#  ===================================================
#
# SteamLine STL702B ['702B', '702C']
# Velocity (m/s)                        32.21
# Tot Loss (J/kg)                     6997.61
# Heat Loss (J/kg)                    2162.59
# d K.E. (J/kg)                          0.00
# d P.E. (J/kg)                          0.00
# Friction Loss (J/kg)                4835.02
#   Skin Friction (J/kg)              1633.40
#   Expansion (J/kg)                     0.00
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)          3201.62
# Inlet Pressure (Mpaa)                  0.81
# Outlet Pressure (Mpaa)                 0.78
# SF_in (kg/s)                         116.05
# SF_out (kg/s)                        115.74
#
#  ===================================================
#
# SteamLine STL702IF ['702C', '702IF']
# Velocity (m/s)                        43.18
# Tot Loss (J/kg)                    38675.65
# Heat Loss (J/kg)                    9412.70
# d K.E. (J/kg)                          0.00
# d P.E. (J/kg)                       -981.00
# Friction Loss (J/kg)               30243.95
#   Skin Friction (J/kg)             16262.10
#   Expansion (J/kg)                     0.00
#   Contraction (J/kg)                   0.00
#   Fittings Friction (J/kg)         13981.84
# Inlet Pressure (Mpaa)                  0.78
# Outlet Pressure (Mpaa)                 0.61
# SF_in (kg/s)                         149.21
# SF_out (kg/s)                        147.16
#
#  ===================================================

# %%
#node_out['STL701A'].append(99)
#print(node_out)

df_out = pd.DataFrame(node_out)
df_out = df_out.transpose()
df_out.columns=['Pressure', 'SteamFlow', 'Velocity', 'TotalLoss', 'HeatLoss', 'SkinFriction', 'Expansion', \
                'Contraction', 'Fittings', 'InletPressure', 'OutletPressure', 'SF_in', 'SF_out' ]
df_out['dSF']=df_out['SF_in']-df_out['SF_out']
df_out['d%SF']=100*df_out['dSF']/df_out['SF_in']
df_out['dP']=df_out['InletPressure']-df_out['OutletPressure']
df_out.head(15)

df_out.iloc[:,[4,5,6,7,8]].plot.bar(stacked=True, figsize=(14,7), grid=True)
#df_out['TotalLoss'].plot(kind='bar', figsize = (12,7), title='Total Loss (J/kg)', grid=True)
#df_out.plot.bar(stacked=True)
#plt.show()
df_out.head(15)
# Out:
#           Pressure   SteamFlow   Velocity     TotalLoss      HeatLoss  \
# STL501    0.831758   50.409827  26.088028  11688.833021   6063.472357
# STL502    0.827284   77.082503  13.811428  13285.814888  11453.126208
# STL503    0.829827  116.212214  20.247299  11351.738115   7812.599327
# STL504    0.840011   42.111066  21.778628   9918.687820   6101.145947
# STL505    0.839252   93.091013  26.370871  10417.698899   5038.687817
# STL506    0.834857   49.645624  25.688154  11189.298489   5788.387521
# STL508    0.773770   33.475789  19.355930   2207.017002    531.337982
# STL701A   0.831468  142.644386  25.097374   2565.762912    453.262297
# STL701B   0.793572  142.165285  38.798997   8779.618434   1770.124223
# STL701IF  0.638696  140.357838  40.420126  35545.174487   9931.677031
# STL702A   0.813796  116.045748  31.668886   3720.930231    361.919043
# STL702B   0.778986  149.211214  32.214923   6997.607202   2162.591638
# STL702IF  0.614112  147.161262  43.176913  38675.648249   9412.700396
#
#           SkinFriction   Expansion  Contraction      Fittings  InletPressure  \
# STL501     2806.292115  170.045077          0.0   2099.605277       0.880000
# STL502      830.742312   47.660520          0.0    588.480893       0.880000
# STL503     1724.034698  102.427309          0.0   1264.705350       0.880000
# STL504     1665.597921  118.506620          0.0   1463.242153       0.880000
# STL505     2406.799164  173.752290          0.0   2145.379511       0.880000
# STL506     2560.547763  164.872179          0.0   2035.733716       0.880000
# STL508       89.631524   93.607283          0.0   1155.801445       0.780000
# STL701A     169.326502    0.000000          0.0   1943.174114       0.839252
# STL701B    2365.451901    0.000000          0.0   4644.042310       0.831468
# STL701IF  14341.098201    0.000000          0.0  12253.399255       0.793572
# STL702A     265.008053    0.000000          0.0   3094.003135       0.829827
# STL702B    1633.398633    0.000000          0.0   3201.616931       0.813796
# STL702IF  16262.104275    0.000000          0.0  13981.843578       0.778986
#
#           OutletPressure       SF_in      SF_out       dSF      d%SF        dP
# STL501          0.831758   50.643664   50.409827  0.233836  0.461729  0.048242
# STL502          0.822810   26.811584   26.672675  0.138909  0.518092  0.057190
# STL503          0.832369   39.305287   39.129711  0.175576  0.446697  0.047631
# STL504          0.840011   42.277996   42.111066  0.166930  0.394838  0.039989
# STL505          0.838493   51.192738   50.979947  0.212791  0.415666  0.041507
# STL506          0.834857   49.867406   49.645624  0.221781  0.444742  0.045143
# STL508          0.773770   33.506431   33.475789  0.030642  0.091450  0.006230
# STL701A         0.828079   93.091013   92.998761  0.092252  0.099099  0.011173
# STL701B         0.793572  142.644386  142.165285  0.479100  0.335871  0.037895
# STL701IF        0.638696  142.165285  140.357838  1.807447  1.271370  0.154876
# STL702A         0.813796  116.212214  116.045748  0.166466  0.143243  0.016030
# STL702B         0.784203  116.045748  115.735425  0.310323  0.267415  0.029594
# STL702IF        0.614112  149.211214  147.161262  2.049952  1.373859  0.164874

# %%
#In [129]: df.plot(subplots=True, figsize=(6, 6));
df_out.iloc[:,[9,10,15]].plot.bar(stacked=False, figsize=(14,7), grid=True)# ylim=(0.5, 1.0))

# %%
df_out.iloc[:,[2,3,14, 15]].plot.bar(stacked=False, figsize=(14,14), grid=True, subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000180A0053E10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000180A0128F28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000180A0178828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000180A01B3588>], dtype=object)
